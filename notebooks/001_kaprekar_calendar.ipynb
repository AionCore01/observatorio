# %% [markdown]
# # 001 - Kaprekar calendar experiment
#
# This notebook mirrors the first Colab-style experiment described in the repository: explore the Kaprekar orbit over a small set of values and summarize the resulting fixed-point behavior.
#
# Internal convention:
# - digit arrays are stored most significant first.
# - if digits are extracted with repeated `% base`, reverse them before reconstruction.

# %%
from observatory.transformers.kaprekar import UniversalKaprekarTransformer

transformer = UniversalKaprekarTransformer(n_digits=4, base=10)
result = transformer.orbit(6174)
result

# %%
from observatory.experiments import base_sweep, summarize_base_sweep

rows = base_sweep(start_base=2, end_base=12, n_digits=4)
summary = summarize_base_sweep(rows)
summary
